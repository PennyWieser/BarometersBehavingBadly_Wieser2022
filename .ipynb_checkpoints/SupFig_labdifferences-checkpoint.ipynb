# %%
import numpy as np
import pandas as pd
import Thermobar as pt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import warnings as w
pd.options.display.max_columns = None

# %% [markdown]
# ## My Dataset

# %%
out=pt.import_excel('Supporting_Data_1.xlsx', sheet_name='Cpx-Liq')
myCpxs1=out['Cpxs']
myLiquids1=out['Liqs']
Cpx_Glass=out['my_input']
notinLEPR= Cpx_Glass['Citation_x'].str.contains('notinLEPR')
notinKeith=(Cpx_Glass['Citation_x'].str.contains('Mercer, C.N., and Johnston, A.D. (2008)'))|(Cpx_Glass['Citation_x'].str.contains('Alonso-Perez, R., Müntener, O., and Ulmer, P. (2009)'))
newMask=notinLEPR|notinKeith
newMask=newMask.fillna(False)

mask_1GPa=Cpx_Glass['P_kbar_x']<=13
mask_1GPa=mask_1GPa.fillna(False)

Press_new=mask_1GPa&newMask
Press_new=Press_new.fillna(False)
Cpx_Glass_filt=Cpx_Glass.loc[Press_new]
myCpxs1_filt=myCpxs1.loc[Press_new]
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_28236\1678094124.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   notinKeith=(Cpx_Glass['Citation_x'].str.contains('Mercer, C.N., and Johnston, A.D. (2008)'))|(Cpx_Glass['Citation_x'].str.contains('Alonso-Perez, R., Müntener, O., and Ulmer, P. (2009)'))

# %% [markdown]
# ## LEPR Dataset

# %%
LEPR_Stitched2=pd.read_excel('../LEPR_All_Cpx.xlsx', sheet_name='Clinopyroxene')
LEPR_Exp=pd.read_excel('../LEPR_All_Cpx.xlsx', sheet_name='Experiment')
LEPR_Liqs=pd.read_excel('../LEPR_All_Cpx.xlsx', sheet_name='Liquid')
LEPR_Liqs_c=LEPR_Liqs.add_suffix("_Liq")
LEPR_Liqs_c2=LEPR_Liqs_c.rename(columns={'Experiment_Liq': 'Experiment'})
LEPR_Stitched1=LEPR_Stitched2.merge(LEPR_Exp, how='right', on='Experiment')
LEPR_CPX_GLASS=LEPR_Liqs_c2.merge(LEPR_Stitched1, how='right', on='Experiment')

# %%
plt.plot(LEPR_CPX_GLASS['MgO value_Liq'], 
         LEPR_CPX_GLASS['MgO value'], 'or')

# %%
LEPR_Stitched_15kbar=LEPR_Stitched1.loc[LEPR_Stitched1[x]<=13]

# %%
x='P (GPa)'
y='T (C)'
MIT=LEPR_Stitched1['Laboratory']=="Massachusetts Institute of Technology"
RNAS=LEPR_Stitched1['Laboratory']=="Russian Academy of Sciences, Moscow"
Lamont=LEPR_Stitched1['Laboratory']=="Lamont Doherty Earth Institute of Columbia University"
TAS=LEPR_Stitched1['Laboratory']=="University of Tasmania"
ANU=LEPR_Stitched1['Laboratory']=="Research School of Earth Sciences, Australian National University (ANU), Canberra, Australia"
SUNY=LEPR_Stitched1['Laboratory']=="State University of New York (SUNY), Stony Brook"
plt.plot(LEPR_Stitched1[x].loc[MIT],
         LEPR_Stitched1[y].loc[MIT],
         'ok', mfc='yellow')
         
plt.plot(LEPR_Stitched1[x].loc[RNAS],
         LEPR_Stitched1[y].loc[RNAS],
         'sk', mfc='red')
plt.plot(LEPR_Stitched1[x].loc[Lamont],
         LEPR_Stitched1[y].loc[Lamont],
         '*k', mfc='grey', ms=10)
plt.plot(LEPR_Stitched1[x].loc[TAS],
         LEPR_Stitched1[y].loc[TAS],
         '*k', mfc='k', ms=10)
plt.plot(LEPR_Stitched1[x].loc[ANU],
         LEPR_Stitched1[y].loc[ANU],
         '+k', mfc='k', ms=10)
plt.plot(LEPR_Stitched1[x].loc[SUNY],
         LEPR_Stitched1[y].loc[SUNY],
         'pk', mfc='w', ms=5)

# %%
LEPR_CPX_GLASS.columns.unique()#
#.head()
# Out:
# Index(['Index_Liq', 'Experiment', 'Citation_Liq', 'Label_Liq', 'Spatial_Liq',
#        'Number of analyses_Liq', 'SiO2 value_Liq', 'SiO2 error_Liq',
#        'SiO2 method_Liq', 'SiO2 units_Liq',
#        ...
#        'H value', 'H error', 'H method', 'H units', 'H standard', 'D value',
#        'D error', 'D method', 'D units', 'D standard'],
#       dtype='object', length=987)

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, figsize = (12,10)) # adjust dimensions of figure here

MIT=LEPR_CPX_GLASS['Laboratory']=="Massachusetts Institute of Technology"
RNAS=LEPR_CPX_GLASS['Laboratory']=="Russian Academy of Sciences, Moscow"
Lamont=LEPR_CPX_GLASS['Laboratory']=="Lamont Doherty Earth Institute of Columbia University"
TAS=LEPR_CPX_GLASS['Laboratory']=="University of Tasmania"
ANU=LEPR_CPX_GLASS['Laboratory']=="Research School of Earth Sciences, Australian National University (ANU), Canberra, Australia"
SUNY=LEPR_CPX_GLASS['Laboratory']=="State University of New York (SUNY), Stony Brook"
x='T (C)'#'SiO2 value_Liq'
y='P (GPa)' #'P (GPa)'

ax0.plot(LEPR_CPX_GLASS[x].loc[MIT],
         LEPR_CPX_GLASS[y].loc[MIT],
         'ok', mfc='yellow')
ax0.plot(LEPR_CPX_GLASS[x].loc[ANU],
         LEPR_CPX_GLASS[y].loc[ANU],
         '+k', mfc='k', ms=10)         

ax0.plot(LEPR_CPX_GLASS[x].loc[TAS],
         LEPR_CPX_GLASS[y].loc[TAS],
        '*k', mfc='k', ms=10)
ax0.set_xlabel('Temperature (C)')
ax0.set_ylabel('Pressure (GPa)')
######

x='SiO2 value_Liq'#'SiO2 value_Liq'
y='P (GPa)' #'P (GPa)'

ax1.plot(LEPR_CPX_GLASS[x].loc[MIT],
         LEPR_CPX_GLASS[y].loc[MIT],
         'ok', mfc='yellow')
ax1.plot(LEPR_CPX_GLASS[x].loc[ANU],
         LEPR_CPX_GLASS[y].loc[ANU],
         '+k', mfc='k', ms=10)         

ax1.plot(LEPR_CPX_GLASS[x].loc[TAS],
         LEPR_CPX_GLASS[y].loc[TAS],
        '*k', mfc='k', ms=10)
ax1.set_xlabel('SiO$_2$ Liq')
ax1.set_ylabel('Pressure (GPa)')

y='P (GPa)'#'SiO2 value_Liq'
x='Na2O value' #'P (GPa)'

ax2.plot(LEPR_CPX_GLASS[x].loc[MIT],
         LEPR_CPX_GLASS[y].loc[MIT],
         'ok', mfc='yellow')
ax2.plot(LEPR_CPX_GLASS[x].loc[ANU],
         LEPR_CPX_GLASS[y].loc[ANU],
         '+k', mfc='k', ms=10)         

ax2.plot(LEPR_CPX_GLASS[x].loc[TAS],
         LEPR_CPX_GLASS[y].loc[TAS],
        '*k', mfc='k', ms=10)
ax2.set_xlabel('Na$_2$O Cpx')
ax2.set_ylabel('Pressure (GPa)')


y='P (GPa)'#'SiO2 value_Liq'
x='Al2O3 value' #'P (GPa)'

ax3.plot(LEPR_CPX_GLASS[x].loc[MIT],
         LEPR_CPX_GLASS[y].loc[MIT],
         'ok', mfc='yellow')
ax3.plot(LEPR_CPX_GLASS[x].loc[ANU],
         LEPR_CPX_GLASS[y].loc[ANU],
         '+k', mfc='k', ms=10)         

ax3.plot(LEPR_CPX_GLASS[x].loc[TAS],
         LEPR_CPX_GLASS[y].loc[TAS],
        '*k', mfc='k', ms=10)
ax3.set_xlabel('Al$_2$O$_3$ Cpx')
ax3.set_ylabel('Pressure (GPa)')
fig.savefig('Nonuniform_Experiments.png', dpi=200)

# %%
LEPR_Stitched_15kbarx, LEPR_Stitched_15kbar['T (C)'],
# Out:
#       Index_x Experiment                                         Citation_x  \
# 0          52   Jor46.20  Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 1          53    Jor46.5  Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 2          54   Jor46.10  Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 3          55    Jor46.8  Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 4          59    Jor46.9  Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# ...       ...        ...                                                ...
# 5478    65318      35-5B  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5479    65318      35-5B  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5480    65319      35-4A  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5481    65319      35-4A  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5482    66681      TJ-15  Vander Auwera, J.V., Longhi, J., and Duchesne,...
#
#       Date            Label Spatial  Number of analyses  SiO2 value  \
# 0     2004  Clinopyroxene 1     NaN                 NaN   51.200001
# 1     2004  Clinopyroxene 1     NaN                 NaN   50.700001
# 2     2004  Clinopyroxene 1     NaN                 NaN   51.400002
# 3     2004  Clinopyroxene 1     NaN                 NaN   51.599998
# 4     2004  Clinopyroxene 1     NaN                 NaN   50.799999
# ...    ...              ...     ...                 ...         ...
# 5478  1989  Clinopyroxene 1     NaN                 NaN   51.900000
# 5479  1989  Clinopyroxene 2     NaN                 NaN   52.100000
# 5480  1989  Clinopyroxene 1     NaN                 NaN   51.900000
# 5481  1989  Clinopyroxene 2     NaN                 NaN   52.500000
# 5482  2000  Clinopyroxene 1     NaN                 NaN   49.940000
#
#       SiO2 error SiO2 method SiO2 units        SiO2 standard  TiO2 value  \
# 0          0.011         EMP        wt%        Not Specified        0.86
# 1          0.013         EMP        wt%        Not Specified        0.85
# 2          0.012         EMP        wt%        Not Specified        0.70
# 3          0.019         EMP        wt%        Not Specified        0.90
# 4          0.006         EMP        wt%        Not Specified        0.86
# ...          ...         ...        ...                  ...         ...
# 5478         NaN         EMP        wt%              Chicago         NaN
# 5479         NaN        SIMS        wt%              Chicago         NaN
# 5480         NaN         EMP        wt%              Chicago         NaN
# 5481         NaN        SIMS        wt%              Chicago         NaN
# 5482       0.800         EMP        wt%  Columbia University        1.27
#
#       TiO2 error TiO2 method TiO2 units        TiO2 standard  Al2O3 value  \
# 0           0.27         EMP        wt%        Not Specified         2.50
# 1           0.04         EMP        wt%        Not Specified         2.70
# 2           0.19         EMP        wt%        Not Specified         2.70
# 3           0.04         EMP        wt%        Not Specified         2.60
# 4           0.13         EMP        wt%        Not Specified         2.90
# ...          ...         ...        ...                  ...          ...
# 5478         NaN         NaN        NaN                  NaN         4.70
# 5479         NaN         NaN        NaN                  NaN         4.93
# 5480         NaN         NaN        NaN                  NaN         5.28
# 5481         NaN         NaN        NaN                  NaN         5.19
# 5482        0.24         EMP        wt%  Columbia University         5.54
#
#       Al2O3 error Al2O3 method Al2O3 units       Al2O3 standard  Fe2O3 value  \
# 0           0.090          EMP         wt%        Not Specified          NaN
# 1           0.010          EMP         wt%        Not Specified          NaN
# 2           0.007          EMP         wt%        Not Specified          NaN
# 3           0.011          EMP         wt%        Not Specified          NaN
# 4           0.030          EMP         wt%        Not Specified          NaN
# ...           ...          ...         ...                  ...          ...
# 5478          NaN          EMP         wt%              Chicago          NaN
# 5479          NaN         SIMS         wt%              Chicago          NaN
# 5480          NaN          EMP         wt%              Chicago          NaN
# 5481          NaN         SIMS         wt%              Chicago          NaN
# 5482        0.700          EMP         wt%  Columbia University          NaN
#
#       Fe2O3 error Fe2O3 method Fe2O3 units Fe2O3 standard  Cr2O3 value  \
# 0             NaN          NaN         NaN            NaN          NaN
# 1             NaN          NaN         NaN            NaN          NaN
# 2             NaN          NaN         NaN            NaN          NaN
# 3             NaN          NaN         NaN            NaN          NaN
# 4             NaN          NaN         NaN            NaN          NaN
# ...           ...          ...         ...            ...          ...
# 5478          NaN          NaN         NaN            NaN          NaN
# 5479          NaN          NaN         NaN            NaN          NaN
# 5480          NaN          NaN         NaN            NaN          NaN
# 5481          NaN          NaN         NaN            NaN          NaN
# 5482          NaN          NaN         NaN            NaN          1.0
#
#       Cr2O3 error Cr2O3 method Cr2O3 units       Cr2O3 standard  FeO value  \
# 0             NaN          NaN         NaN                  NaN       5.90
# 1             NaN          NaN         NaN                  NaN       5.80
# 2             NaN          NaN         NaN                  NaN       6.00
# 3             NaN          NaN         NaN                  NaN       6.30
# 4             NaN          NaN         NaN                  NaN       6.70
# ...           ...          ...         ...                  ...        ...
# 5478          NaN          NaN         NaN                  NaN        NaN
# 5479          NaN          NaN         NaN                  NaN        NaN
# 5480          NaN          NaN         NaN                  NaN        NaN
# 5481          NaN          NaN         NaN                  NaN        NaN
# 5482         0.11          EMP         wt%  Columbia University      17.59
#
#       FeO error FeO method FeO units         FeO standard  MnO value  \
# 0         0.090        EMP       wt%        Not Specified       0.12
# 1         0.010        EMP       wt%        Not Specified       0.12
# 2         0.050        EMP       wt%        Not Specified       0.08
# 3         0.009        EMP       wt%        Not Specified       0.11
# 4         0.009        EMP       wt%        Not Specified       0.15
# ...         ...        ...       ...                  ...        ...
# 5478        NaN        NaN       NaN                  NaN        NaN
# 5479        NaN        NaN       NaN                  NaN        NaN
# 5480        NaN        NaN       NaN                  NaN        NaN
# 5481        NaN        NaN       NaN                  NaN        NaN
# 5482      0.750        EMP       wt%  Columbia University       0.25
#
#       MnO error MnO method MnO units         MnO standard  MgO value  \
# 0          0.02        EMP       wt%        Not Specified      15.50
# 1          0.02        EMP       wt%        Not Specified      15.80
# 2          0.02        EMP       wt%        Not Specified      15.60
# 3          0.04        EMP       wt%        Not Specified      15.40
# 4          0.06        EMP       wt%        Not Specified      15.40
# ...         ...        ...       ...                  ...        ...
# 5478        NaN        NaN       NaN                  NaN      17.63
# 5479        NaN        NaN       NaN                  NaN      17.82
# 5480        NaN        NaN       NaN                  NaN      17.53
# 5481        NaN        NaN       NaN                  NaN      17.46
# 5482       0.03        EMP       wt%  Columbia University      18.06
#
#       MgO error MgO method MgO units         MgO standard  NiO value  \
# 0         0.070        EMP       wt%        Not Specified        NaN
# 1         0.010        EMP       wt%        Not Specified        NaN
# 2         0.060        EMP       wt%        Not Specified        NaN
# 3         0.011        EMP       wt%        Not Specified        NaN
# 4         0.040        EMP       wt%        Not Specified        NaN
# ...         ...        ...       ...                  ...        ...
# 5478        NaN        EMP       wt%              Chicago        NaN
# 5479        NaN       SIMS       wt%              Chicago        NaN
# 5480        NaN        EMP       wt%              Chicago        NaN
# 5481        NaN       SIMS       wt%              Chicago        NaN
# 5482      1.340        EMP       wt%  Columbia University        NaN
#
#       NiO error NiO method NiO units NiO standard  CoO value  CoO error  \
# 0           NaN        NaN       NaN          NaN        NaN        NaN
# 1           NaN        NaN       NaN          NaN        NaN        NaN
# 2           NaN        NaN       NaN          NaN        NaN        NaN
# 3           NaN        NaN       NaN          NaN        NaN        NaN
# 4           NaN        NaN       NaN          NaN        NaN        NaN
# ...         ...        ...       ...          ...        ...        ...
# 5478        NaN        NaN       NaN          NaN        NaN        NaN
# 5479        NaN        NaN       NaN          NaN        NaN        NaN
# 5480        NaN        NaN       NaN          NaN        NaN        NaN
# 5481        NaN        NaN       NaN          NaN        NaN        NaN
# 5482        NaN        NaN       NaN          NaN        NaN        NaN
#
#      CoO method CoO units CoO standard  CaO value  CaO error CaO method  \
# 0           NaN       NaN          NaN  22.290001       0.23        EMP
# 1           NaN       NaN          NaN  22.100000       0.22        EMP
# 2           NaN       NaN          NaN  22.340000       0.04        EMP
# 3           NaN       NaN          NaN  22.000000       0.28        EMP
# 4           NaN       NaN          NaN  22.010000       0.41        EMP
# ...         ...       ...          ...        ...        ...        ...
# 5478        NaN       NaN          NaN  23.680000        NaN        EMP
# 5479        NaN       NaN          NaN  22.800000        NaN       SIMS
# 5480        NaN       NaN          NaN  23.870000        NaN        EMP
# 5481        NaN       NaN          NaN  22.760000        NaN       SIMS
# 5482        NaN       NaN          NaN   7.070000       1.49        EMP
#
#      CaO units         CaO standard  Na2O value  Na2O error Na2O method  \
# 0          wt%        Not Specified       0.460        0.09         EMP
# 1          wt%        Not Specified       0.380        0.07         EMP
# 2          wt%        Not Specified       0.470        0.06         EMP
# 3          wt%        Not Specified       0.470        0.08         EMP
# 4          wt%        Not Specified       0.490        0.06         EMP
# ...        ...                  ...         ...         ...         ...
# 5478       wt%              Chicago       0.291         NaN         EMP
# 5479       wt%              Chicago       0.236         NaN        SIMS
# 5480       wt%              Chicago       0.280         NaN         EMP
# 5481       wt%              Chicago       0.280         NaN        SIMS
# 5482       wt%  Columbia University       0.500        0.08         EMP
#
#      Na2O units        Na2O standard  K2O value  K2O error K2O method  \
# 0           wt%        Not Specified        NaN        NaN        NaN
# 1           wt%        Not Specified        NaN        NaN        NaN
# 2           wt%        Not Specified        NaN        NaN        NaN
# 3           wt%        Not Specified        NaN        NaN        NaN
# 4           wt%        Not Specified        NaN        NaN        NaN
# ...         ...                  ...        ...        ...        ...
# 5478        wt%              Chicago        NaN        NaN        NaN
# 5479        wt%              Chicago        NaN        NaN        NaN
# 5480        wt%              Chicago        NaN        NaN        NaN
# 5481        wt%              Chicago        NaN        NaN        NaN
# 5482        wt%  Columbia University        0.0        0.0        EMP
#
#      K2O units         K2O standard  P2O5 value  P2O5 error P2O5 method  \
# 0          NaN                  NaN         NaN         NaN         NaN
# 1          NaN                  NaN         NaN         NaN         NaN
# 2          NaN                  NaN         NaN         NaN         NaN
# 3          NaN                  NaN         NaN         NaN         NaN
# 4          NaN                  NaN         NaN         NaN         NaN
# ...        ...                  ...         ...         ...         ...
# 5478       NaN                  NaN         NaN         NaN         NaN
# 5479       NaN                  NaN         NaN         NaN         NaN
# 5480       NaN                  NaN         NaN         NaN         NaN
# 5481       NaN                  NaN         NaN         NaN         NaN
# 5482       wt%  Columbia University         0.0         0.0         EMP
#
#      P2O5 units        P2O5 standard  H2O value  H2O error H2O method  \
# 0           NaN                  NaN        NaN        NaN        NaN
# 1           NaN                  NaN        NaN        NaN        NaN
# 2           NaN                  NaN        NaN        NaN        NaN
# 3           NaN                  NaN        NaN        NaN        NaN
# 4           NaN                  NaN        NaN        NaN        NaN
# ...         ...                  ...        ...        ...        ...
# 5478        NaN                  NaN        NaN        NaN        NaN
# 5479        NaN                  NaN        NaN        NaN        NaN
# 5480        NaN                  NaN        NaN        NaN        NaN
# 5481        NaN                  NaN        NaN        NaN        NaN
# 5482        wt%  Columbia University        NaN        NaN        NaN
#
#      H2O units H2O standard  CO2 value  CO2 error  CO2 method  CO2 units  \
# 0          NaN          NaN        NaN        NaN         NaN        NaN
# 1          NaN          NaN        NaN        NaN         NaN        NaN
# 2          NaN          NaN        NaN        NaN         NaN        NaN
# 3          NaN          NaN        NaN        NaN         NaN        NaN
# 4          NaN          NaN        NaN        NaN         NaN        NaN
# ...        ...          ...        ...        ...         ...        ...
# 5478       NaN          NaN        NaN        NaN         NaN        NaN
# 5479       NaN          NaN        NaN        NaN         NaN        NaN
# 5480       NaN          NaN        NaN        NaN         NaN        NaN
# 5481       NaN          NaN        NaN        NaN         NaN        NaN
# 5482       NaN          NaN        NaN        NaN         NaN        NaN
#
#       CO2 standard  D2O value  D2O error  D2O method  D2O units  D2O standard  \
# 0              NaN        NaN        NaN         NaN        NaN           NaN
# 1              NaN        NaN        NaN         NaN        NaN           NaN
# 2              NaN        NaN        NaN         NaN        NaN           NaN
# 3              NaN        NaN        NaN         NaN        NaN           NaN
# 4              NaN        NaN        NaN         NaN        NaN           NaN
# ...            ...        ...        ...         ...        ...           ...
# 5478           NaN        NaN        NaN         NaN        NaN           NaN
# 5479           NaN        NaN        NaN         NaN        NaN           NaN
# 5480           NaN        NaN        NaN         NaN        NaN           NaN
# 5481           NaN        NaN        NaN         NaN        NaN           NaN
# 5482           NaN        NaN        NaN         NaN        NaN           NaN
#
#       Fe83Si17 value  Fe83Si17 error  Fe83Si17 method  Fe83Si17 units  \
# 0                NaN             NaN              NaN             NaN
# 1                NaN             NaN              NaN             NaN
# 2                NaN             NaN              NaN             NaN
# 3                NaN             NaN              NaN             NaN
# 4                NaN             NaN              NaN             NaN
# ...              ...             ...              ...             ...
# 5478             NaN             NaN              NaN             NaN
# 5479             NaN             NaN              NaN             NaN
# 5480             NaN             NaN              NaN             NaN
# 5481             NaN             NaN              NaN             NaN
# 5482             NaN             NaN              NaN             NaN
#
#       Fe83Si17 standard  FeSi value  FeSi error  FeSi method  FeSi units  \
# 0                   NaN         NaN         NaN          NaN         NaN
# 1                   NaN         NaN         NaN          NaN         NaN
# 2                   NaN         NaN         NaN          NaN         NaN
# 3                   NaN         NaN         NaN          NaN         NaN
# 4                   NaN         NaN         NaN          NaN         NaN
# ...                 ...         ...         ...          ...         ...
# 5478                NaN         NaN         NaN          NaN         NaN
# 5479                NaN         NaN         NaN          NaN         NaN
# 5480                NaN         NaN         NaN          NaN         NaN
# 5481                NaN         NaN         NaN          NaN         NaN
# 5482                NaN         NaN         NaN          NaN         NaN
#
#       FeSi standard  FeS value  FeS error  FeS method  FeS units  \
# 0               NaN        NaN        NaN         NaN        NaN
# 1               NaN        NaN        NaN         NaN        NaN
# 2               NaN        NaN        NaN         NaN        NaN
# 3               NaN        NaN        NaN         NaN        NaN
# 4               NaN        NaN        NaN         NaN        NaN
# ...             ...        ...        ...         ...        ...
# 5478            NaN        NaN        NaN         NaN        NaN
# 5479            NaN        NaN        NaN         NaN        NaN
# 5480            NaN        NaN        NaN         NaN        NaN
# 5481            NaN        NaN        NaN         NaN        NaN
# 5482            NaN        NaN        NaN         NaN        NaN
#
#       FeS standard  WO3 value  WO3 error  WO3 method  WO3 units  WO3 standard  \
# 0              NaN        NaN        NaN         NaN        NaN           NaN
# 1              NaN        NaN        NaN         NaN        NaN           NaN
# 2              NaN        NaN        NaN         NaN        NaN           NaN
# 3              NaN        NaN        NaN         NaN        NaN           NaN
# 4              NaN        NaN        NaN         NaN        NaN           NaN
# ...            ...        ...        ...         ...        ...           ...
# 5478           NaN        NaN        NaN         NaN        NaN           NaN
# 5479           NaN        NaN        NaN         NaN        NaN           NaN
# 5480           NaN        NaN        NaN         NaN        NaN           NaN
# 5481           NaN        NaN        NaN         NaN        NaN           NaN
# 5482           NaN        NaN        NaN         NaN        NaN           NaN
#
#       ReO3 value  ReO3 error  ReO3 method  ReO3 units  ReO3 standard  \
# 0            NaN         NaN          NaN         NaN            NaN
# 1            NaN         NaN          NaN         NaN            NaN
# 2            NaN         NaN          NaN         NaN            NaN
# 3            NaN         NaN          NaN         NaN            NaN
# 4            NaN         NaN          NaN         NaN            NaN
# ...          ...         ...          ...         ...            ...
# 5478         NaN         NaN          NaN         NaN            NaN
# 5479         NaN         NaN          NaN         NaN            NaN
# 5480         NaN         NaN          NaN         NaN            NaN
# 5481         NaN         NaN          NaN         NaN            NaN
# 5482         NaN         NaN          NaN         NaN            NaN
#
#       Mg(OH)2 value  Mg(OH)2 error  Mg(OH)2 method  Mg(OH)2 units  \
# 0               NaN            NaN             NaN            NaN
# 1               NaN            NaN             NaN            NaN
# 2               NaN            NaN             NaN            NaN
# 3               NaN            NaN             NaN            NaN
# 4               NaN            NaN             NaN            NaN
# ...             ...            ...             ...            ...
# 5478            NaN            NaN             NaN            NaN
# 5479            NaN            NaN             NaN            NaN
# 5480            NaN            NaN             NaN            NaN
# 5481            NaN            NaN             NaN            NaN
# 5482            NaN            NaN             NaN            NaN
#
#       Mg(OH)2 standard  Tb2O3 value  Tb2O3 error  Tb2O3 method  Tb2O3 units  \
# 0                  NaN          NaN          NaN           NaN          NaN
# 1                  NaN          NaN          NaN           NaN          NaN
# 2                  NaN          NaN          NaN           NaN          NaN
# 3                  NaN          NaN          NaN           NaN          NaN
# 4                  NaN          NaN          NaN           NaN          NaN
# ...                ...          ...          ...           ...          ...
# 5478               NaN          NaN          NaN           NaN          NaN
# 5479               NaN          NaN          NaN           NaN          NaN
# 5480               NaN          NaN          NaN           NaN          NaN
# 5481               NaN          NaN          NaN           NaN          NaN
# 5482               NaN          NaN          NaN           NaN          NaN
#
#       Tb2O3 standard  OH value  OH error  OH method  OH units  OH standard  \
# 0                NaN       NaN       NaN        NaN       NaN          NaN
# 1                NaN       NaN       NaN        NaN       NaN          NaN
# 2                NaN       NaN       NaN        NaN       NaN          NaN
# 3                NaN       NaN       NaN        NaN       NaN          NaN
# 4                NaN       NaN       NaN        NaN       NaN          NaN
# ...              ...       ...       ...        ...       ...          ...
# 5478             NaN       NaN       NaN        NaN       NaN          NaN
# 5479             NaN       NaN       NaN        NaN       NaN          NaN
# 5480             NaN       NaN       NaN        NaN       NaN          NaN
# 5481             NaN       NaN       NaN        NaN       NaN          NaN
# 5482             NaN       NaN       NaN        NaN       NaN          NaN
#
#       He value  He error  He method  He units  He standard  Ne value  \
# 0          NaN       NaN        NaN       NaN          NaN       NaN
# 1          NaN       NaN        NaN       NaN          NaN       NaN
# 2          NaN       NaN        NaN       NaN          NaN       NaN
# 3          NaN       NaN        NaN       NaN          NaN       NaN
# 4          NaN       NaN        NaN       NaN          NaN       NaN
# ...        ...       ...        ...       ...          ...       ...
# 5478       NaN       NaN        NaN       NaN          NaN       NaN
# 5479       NaN       NaN        NaN       NaN          NaN       NaN
# 5480       NaN       NaN        NaN       NaN          NaN       NaN
# 5481       NaN       NaN        NaN       NaN          NaN       NaN
# 5482       NaN       NaN        NaN       NaN          NaN       NaN
#
#       Ne error  Ne method  Ne units  Ne standard  Ar value  Ar error  \
# 0          NaN        NaN       NaN          NaN       NaN       NaN
# 1          NaN        NaN       NaN          NaN       NaN       NaN
# 2          NaN        NaN       NaN          NaN       NaN       NaN
# 3          NaN        NaN       NaN          NaN       NaN       NaN
# 4          NaN        NaN       NaN          NaN       NaN       NaN
# ...        ...        ...       ...          ...       ...       ...
# 5478       NaN        NaN       NaN          NaN       NaN       NaN
# 5479       NaN        NaN       NaN          NaN       NaN       NaN
# 5480       NaN        NaN       NaN          NaN       NaN       NaN
# 5481       NaN        NaN       NaN          NaN       NaN       NaN
# 5482       NaN        NaN       NaN          NaN       NaN       NaN
#
#       Ar method  Ar units  Ar standard  Kr value  Kr error  Kr method  \
# 0           NaN       NaN          NaN       NaN       NaN        NaN
# 1           NaN       NaN          NaN       NaN       NaN        NaN
# 2           NaN       NaN          NaN       NaN       NaN        NaN
# 3           NaN       NaN          NaN       NaN       NaN        NaN
# 4           NaN       NaN          NaN       NaN       NaN        NaN
# ...         ...       ...          ...       ...       ...        ...
# 5478        NaN       NaN          NaN       NaN       NaN        NaN
# 5479        NaN       NaN          NaN       NaN       NaN        NaN
# 5480        NaN       NaN          NaN       NaN       NaN        NaN
# 5481        NaN       NaN          NaN       NaN       NaN        NaN
# 5482        NaN       NaN          NaN       NaN       NaN        NaN
#
#       Kr units  Kr standard  Xe value  Xe error  Xe method  Xe units  \
# 0          NaN          NaN       NaN       NaN        NaN       NaN
# 1          NaN          NaN       NaN       NaN        NaN       NaN
# 2          NaN          NaN       NaN       NaN        NaN       NaN
# 3          NaN          NaN       NaN       NaN        NaN       NaN
# 4          NaN          NaN       NaN       NaN        NaN       NaN
# ...        ...          ...       ...       ...        ...       ...
# 5478       NaN          NaN       NaN       NaN        NaN       NaN
# 5479       NaN          NaN       NaN       NaN        NaN       NaN
# 5480       NaN          NaN       NaN       NaN        NaN       NaN
# 5481       NaN          NaN       NaN       NaN        NaN       NaN
# 5482       NaN          NaN       NaN       NaN        NaN       NaN
#
#       Xe standard  H value  H error  H method  H units  H standard  D value  \
# 0             NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 1             NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 2             NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 3             NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 4             NaN      NaN      NaN       NaN      NaN         NaN      NaN
# ...           ...      ...      ...       ...      ...         ...      ...
# 5478          NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 5479          NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 5480          NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 5481          NaN      NaN      NaN       NaN      NaN         NaN      NaN
# 5482          NaN      NaN      NaN       NaN      NaN         NaN      NaN
#
#       D error  D method  D units  D standard  Index_y  \
# 0         NaN       NaN      NaN         NaN       52
# 1         NaN       NaN      NaN         NaN       53
# 2         NaN       NaN      NaN         NaN       54
# 3         NaN       NaN      NaN         NaN       55
# 4         NaN       NaN      NaN         NaN       59
# ...       ...       ...      ...         ...      ...
# 5478      NaN       NaN      NaN         NaN    65318
# 5479      NaN       NaN      NaN         NaN    65318
# 5480      NaN       NaN      NaN         NaN    65319
# 5481      NaN       NaN      NaN         NaN    65319
# 5482      NaN       NaN      NaN         NaN    66681
#
#                                              Citation_y  \
# 0     Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 1     Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 2     Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 3     Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# 4     Barclay, J., Carmichael, I.S.E. (2004) A hornb...
# ...                                                 ...
# 5478  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5479  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5480  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5481  Kuehner, S.M., Laughlin, J.R., Grossman, L., J...
# 5482  Vander Auwera, J.V., Longhi, J., and Duchesne,...
#
#                                              Laboratory Notes  Rock type  \
# 0                  University of California at Berkeley   NaN        NaN
# 1                  University of California at Berkeley   NaN        NaN
# 2                  University of California at Berkeley   NaN        NaN
# 3                  University of California at Berkeley   NaN        NaN
# 4                  University of California at Berkeley   NaN        NaN
# ...                                                 ...   ...        ...
# 5478                              University of Chicago   NaN        NaN
# 5479                              University of Chicago   NaN        NaN
# 5480                              University of Chicago   NaN        NaN
# 5481                              University of Chicago   NaN        NaN
# 5482  Lamont Doherty Earth Institute of Columbia Uni...   NaN        NaN
#
#      Device Container  Material Doped  P (GPa)  err P (GPa) fO2 condition  \
# 0      IHPV      AgPd       NaN     n   0.2320          5.0          -7.3
# 1      IHPV      AgPd       NaN     n   0.1990          5.0          -5.8
# 2      IHPV      AgPd       NaN     n   0.2210          5.0          -8.4
# 3      IHPV      AgPd       NaN     n   0.2140          5.0          -7.8
# 4      IHPV      AgPd       NaN     n   0.1540          5.0          -7.9
# ...     ...       ...       ...   ...      ...          ...           ...
# 5478  1-atm        Pt       NaN     y   0.0001          NaN           NaN
# 5479  1-atm        Pt       NaN     y   0.0001          NaN           NaN
# 5480  1-atm        Pt       NaN     y   0.0001          NaN           NaN
# 5481  1-atm        Pt       NaN     y   0.0001          NaN           NaN
# 5482     PC         C       NaN     y   1.0000          NaN         QFM-2
#
#       fO2 value  fO2 error   T (C)  err T (C)  Duration (hours)  \
# 0     -7.300000        NaN  1060.0        5.0             49.00
# 1     -5.800000        NaN  1050.0        5.0             48.00
# 2     -8.400000        NaN  1035.0        5.0             48.00
# 3     -7.800000        NaN  1035.0        5.0             48.00
# 4     -7.900000        NaN  1025.0        5.0             48.00
# ...         ...        ...     ...        ...               ...
# 5478        NaN        NaN  1260.0        NaN              6.00
# 5479        NaN        NaN  1260.0        NaN              6.00
# 5480        NaN        NaN  1260.0        NaN              7.25
# 5481        NaN        NaN  1260.0        NaN              7.25
# 5482 -10.008823        NaN  1160.0        2.0             69.00
#
#                      Phases Public     Type
# 0             ol+cpx+spn+ap      y     LEPR
# 1             ol+cpx+spn+ap      y     LEPR
# 2     ol+cpx+amph+bi+spn+ap      y     LEPR
# 3     ol+cpx+amph+bi+spn+ap      y     LEPR
# 4     ol+cpx+amph+bi+spn+ap      y     LEPR
# ...                     ...    ...      ...
# 5478               liq, cpx      y  TraceDs
# 5479               liq, cpx      y  TraceDs
# 5480               liq, cpx      y  TraceDs
# 5481               liq, cpx      y  TraceDs
# 5482  liq,plag,opx,pig,crmt      y  TraceDs
#
# [5424 rows x 187 columns]

# %%
LEPR_Stitched_15kbar['Laboratory'].unique()
# Out:
# array(['University of California at Berkeley', 'University of Oregon',
#        'Lamont-Doherty Earth Observatory, Columbia University',
#        'Tokyo Institute of Technology', 'Brown University',
#        'Orleans, France', 'California Institute of Technology',
#        'Macquarie University, Sydney, Australia',
#        'University of Tasmania', 'Australian National University',
#        'Universität zu Köln, University of Cologne, Germany',
#        'University of Tromso', 'University of Georgia',
#        'Lawrence Livermore National Laboratory',
#        'Université de Bretagne Occidentale', 'University of Manchester',
#        'Carnegie Institution, Washington DC',
#        'Laboratoire Magmas et Volcans, Clermont-Ferrand, France',
#        'University of Tokyo', 'Smithsonian Institution',
#        'Massachusetts Institute of Technology',
#        'Eidgenössische Technische Hochschule Zürich, Swiss Federal Institute of Technology in Zurich',
#        'University of Bristol', 'University of Alberta',
#        'Russian Academy of Sciences, Moscow', 'University of Hannover',
#        'University of Kobe',
#        'Dept. Earth Sci, National Taiwan Normal University, Taipei, Taiwan, Roc',
#        'University of Minnesota',
#        'Bayerisches Geoinstitut, University of Bayreuth, Germany',
#        'University of California at Davis',
#        'Pennsylvania State University',
#        'State University of New York (SUNY), Stony Brook',
#        'Purdue University', 'University of New Brunswick',
#        'University of Bergen, Norway',
#        'University of Washington, Seattle', 'NASA Johnson Space Center',
#        'Stanford University', 'Oak Ridge National Laboratory',
#        'University of Massachussetts', 'Yale University',
#        'Grant Institute of Geology, University of Edinburgh',
#        'University of Illinois, Urbana/Champaign',
#        'United States Geological Survey, Reston, VA',
#        'University of Texas at Dallas',
#        'Institute of Geochemistry, Chinese Academy of Sciences, Guiyang',
#        'University of Innsbruck, Austria', 'Gakushuin University',
#        'Institute of Meteoritics, University of New Mexico',
#        'Sapienza University of Rome', 'University of Chicago',
#        'University of Calgary', 'Tokyo Institute of Technology, Japan',
#        'Woods Hole Oceanographic Institution',
#        'Istituto Nazionale di Geofisica e Vulcanologia (INGV), Rome, Italy',
#        'University of Texas (Dallas)', 'University of Cambridge, UK',
#        'University of Göttingen',
#        'University of Victoria, British Columbia, Canada',
#        'University of Arizona, Tucson, AZ',
#        'Goethe-Universität Frankfurt am Main',
#        'Research School of Earth Sciences, Australian National University (ANU), Canberra, Australia',
#        'Rensselaer Polytechnic Institute, Department of Earth and Environmental Sciences, Troy, New York',
#        'Ibaraki University, Japan',
#        'Le Centre de Recherches Petrographiques et Geochimiques (Center for Petrographic and Geochemical Research) (CRPP), Nancy, France',
#        'Oregon State University', 'University of Alberta, Canada',
#        'Department of Geology, University of Illinois at Urbana-Champaign',
#        'Mineralogisch-Petrologisches Institut, UniversitÃ¤t GÃ¶ttingen, GÃ¶ttingen, (University of GÃ¶ttingen), Germany',
#        'University of California, Santa Cruz',
#        'Mineralogish-Petrologisches-Institut in Gottingen',
#        'Steinmann-Institut, UniversitÃ¤t Bonn (University of Bonn, Germany)',
#        'Guangzhou Institute of Geochemistry, China',
#        'Department of Geology at the University of Maryland',
#        'Lamont Doherty Earth Institute of Columbia University'],
#       dtype=object)

# %% [markdown]
# ## Comparing number at Hannover before and after

# %%
100*(sum(LEPR_Stitched_15kbar['Laboratory']=="University of Hannover")/
len(LEPR_Stitched_15kbar['Laboratory']))
# Out:
# 1.198377581120944

# %%
100*(sum(Cpx_Glass_filt['Laboratory']=="Hannover")/
len(Cpx_Glass_filt['Laboratory']))
# Out:
# 40.0

# %%
100*(sum(LEPR_Stitched_15kbar['Laboratory']=="Massachusetts Institute of Technology")/
len(LEPR_Stitched_15kbar['Laboratory']))
# Out:
# 10.435103244837759

# %%
100*(sum(Cpx_Glass_filt['Laboratory']=="MIT")/
len(Cpx_Glass_filt['Laboratory']))
# Out:
# 10.53763440860215

# %% [markdown]
# ## Number of analyses

# %%
len(Cpx_Glass['N'])
# Out:
# 852

# %%
len(Cpx_Glass.loc[(Cpx_Glass['N_meas_Cpx']>0)&(newMask)&
                  (Cpx_Glass['P_kbar_x']<13)] )
# Out:
# 459

# %%
len(Cpx_Glass.loc[(Cpx_Glass['N_meas_Cpx']>0)&(~newMask)&
                  (Cpx_Glass['P_kbar_x']<13)] )
# Out:
# 295

# %%
plt.hist(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&(newMask)&
                  (Cpx_Glass['P_kbar_x']<13)], density=True)

plt.hist(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&(~newMask)&
                  (Cpx_Glass['P_kbar_x']<13)], density=True, alpha=0.5, bins=100);

# %%
np.mean(
Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&(newMask)&
                  (Cpx_Glass['P_kbar_x']<13)]
)
# Out:
# 7.786492374727668

# %%
np.median(
Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&(newMask)&
                  (Cpx_Glass['P_kbar_x']<13)]
)
# Out:
# 6.0

# %%
np.mean(
Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&(~newMask)&
                  (Cpx_Glass['P_kbar_x']<13)]
)
# Out:
# 8.145762711864407

# %%
np.median(
Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&(~newMask)&
                  (Cpx_Glass['P_kbar_x']<13)]
)
# Out:
# 6.0

# %%
len_dataset=len(
Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>0)&
                  (Cpx_Glass['P_kbar_x']<13)]
)

# %%
Length1=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']==1)&
                  (Cpx_Glass['P_kbar_x']<13)])
Length1
# Out:
# 40

# %%
Length1/len_dataset
# Out:
# 0.05305039787798409

# %%
Length2=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']==2)&
                  (Cpx_Glass['P_kbar_x']<13)])
Length2
# Out:
# 47

# %%
Length2/len_dataset
# Out:
# 0.0623342175066313

# %%
Length3=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']==3)&
                  (Cpx_Glass['P_kbar_x']<13)])
Length3
# Out:
# 67

# %%
Length3/len_dataset
# Out:
# 0.08885941644562334

# %%
Length4=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']==4)&
                  (Cpx_Glass['P_kbar_x']<13)])
Length4
# Out:
# 77

# %%
Length4/len_dataset
# Out:
# 0.10212201591511937

# %%
Length5=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx'].between(0.5, 5.5))&
                  (Cpx_Glass['P_kbar_x']<13)])
Length5
# Out:
# 325

# %%
Length5/len_dataset
# Out:
# 0.43103448275862066

# %%
Length10=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>=10)&
                  (Cpx_Glass['P_kbar_x']<13)])
Length10
# Out:
# 325

# %%
Length10/len_dataset
# Out:
# 0.2519893899204244

# %%
Length20=len(Cpx_Glass['N_meas_Cpx'].loc[(Cpx_Glass['N_meas_Cpx']>=20)&
                  (Cpx_Glass['P_kbar_x']<13)])
Length20
# Out:
# 39

# %%
Length20/len_dataset
# Out:
# 0.05172413793103448
